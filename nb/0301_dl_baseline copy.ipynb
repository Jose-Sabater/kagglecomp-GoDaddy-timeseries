# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %load_ext nb_black
import tensorflow as tf
import math
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %% [markdown]
# ## Strategy: Try baseline ML but instead of filtering on population try it on Active

# %%
train = pd.read_csv("../data/raw/train.csv")
test = pd.read_csv("../data/raw/test.csv")
timeseries = pd.read_csv("../data/processed/timeseries_15_rows_per_county.csv")

# %% [markdown]
# ## Understand the data
# Timeseries is our train dataset but for each cfip we have taken microdensity instances 1-23 and used 24 as target, 2-24, 25 target and so on

# %%
print(f"timeseries shape: {timeseries.shape}")
timeseries.head(20)
# Out:
# timeseries shape: (47025, 29)
#     cfips  POPESTIMATE2021  active    target target_date         0         1  \
# 0    1001            59095    1249  3.219917  2021-08-01  3.007682  2.884870
# 1    1001            59095    1249  3.186722  2021-09-01  2.884870  3.055843
# 2    1001            59095    1249  3.203320  2021-10-01  3.055843  2.993233
# 3    1001            59095    1249  3.200948  2021-11-01  2.993233  2.993233
# 4    1001            59095    1249  3.286307  2021-12-01  2.993233  2.969090
# 5    1001            59095    1249  3.296781  2022-01-01  2.969090  2.909326
# 6    1001            59095    1249  3.334431  2022-02-01  2.909326  2.933231
# 7    1001            59095    1249  3.336785  2022-03-01  2.933231  3.000167
# 8    1001            59095    1249  3.372082  2022-04-01  3.000167  3.004948
# 9    1001            59095    1249  3.313253  2022-05-01  3.004948  3.019292
# 10   1001            59095    1249  3.346197  2022-06-01  3.019292  3.083837
# 11   1001            59095    1249  3.437971  2022-07-01  3.083837  3.174679
# 12   1001            59095    1249  3.423852  2022-08-01  3.174679  3.205756
# 13   1001            59095    1249  3.442677  2022-09-01  3.205756  3.193804
# 14   1001            59095    1249  3.463856  2022-10-01  3.193804  3.038416
# 15   1003           239294   11464  7.918605  2021-08-01  7.239156  7.290936
# 16   1003           239294   11464  7.802155  2021-09-01  7.290936  7.425439
# 17   1003           239294   11464  7.832168  2021-10-01  7.425439  7.426071
# 18   1003           239294   11464  7.900597  2021-11-01  7.426071  7.470274
# 19   1003           239294   11464  7.930010  2021-12-01  7.470274  7.413655
#
#            2         3         4  ...        14        15        16        17  \
# 0   3.055843  2.993233  2.993233  ...  3.193804  3.038416  3.002558  2.947244
# 1   2.993233  2.993233  2.969090  ...  3.038416  3.002558  2.947244  3.106106
# 2   2.993233  2.969090  2.909326  ...  3.002558  2.947244  3.106106  3.144043
# 3   2.969090  2.909326  2.933231  ...  2.947244  3.106106  3.144043  3.224659
# 4   2.909326  2.933231  3.000167  ...  3.106106  3.144043  3.224659  3.227030
# 5   2.933231  3.000167  3.004948  ...  3.144043  3.224659  3.227030  3.222288
# 6   3.000167  3.004948  3.019292  ...  3.224659  3.227030  3.222288  3.210433
# 7   3.004948  3.019292  3.083837  ...  3.227030  3.222288  3.210433  3.219917
# 8   3.019292  3.083837  3.174679  ...  3.222288  3.210433  3.219917  3.186722
# 9   3.083837  3.174679  3.205756  ...  3.210433  3.219917  3.186722  3.203320
# 10  3.174679  3.205756  3.193804  ...  3.219917  3.186722  3.203320  3.200948
# 11  3.205756  3.193804  3.038416  ...  3.186722  3.203320  3.200948  3.286307
# 12  3.193804  3.038416  3.002558  ...  3.203320  3.200948  3.286307  3.296781
# 13  3.038416  3.002558  2.947244  ...  3.200948  3.286307  3.296781  3.334431
# 14  3.002558  2.947244  3.106106  ...  3.286307  3.296781  3.334431  3.336785
# 15  7.425439  7.426071  7.470274  ...  8.329126  8.263252  8.224466  8.011045
# 16  7.426071  7.470274  7.413655  ...  8.263252  8.224466  8.011045  7.909001
# 17  7.470274  7.413655  7.282522  ...  8.224466  8.011045  7.909001  7.978031
# 18  7.413655  7.282522  7.309610  ...  8.011045  7.909001  7.978031  8.032654
# 19  7.282522  7.309610  7.568799  ...  7.909001  7.978031  8.032654  8.061466
#
#           18        19        20        21        22        23
# 0   3.106106  3.144043  3.224659  3.227030  3.222288  3.210433
# 1   3.144043  3.224659  3.227030  3.222288  3.210433  3.219917
# 2   3.224659  3.227030  3.222288  3.210433  3.219917  3.186722
# 3   3.227030  3.222288  3.210433  3.219917  3.186722  3.203320
# 4   3.222288  3.210433  3.219917  3.186722  3.203320  3.200948
# 5   3.210433  3.219917  3.186722  3.203320  3.200948  3.286307
# 6   3.219917  3.186722  3.203320  3.200948  3.286307  3.296781
# 7   3.186722  3.203320  3.200948  3.286307  3.296781  3.334431
# 8   3.203320  3.200948  3.286307  3.296781  3.334431  3.336785
# 9   3.200948  3.286307  3.296781  3.334431  3.336785  3.372082
# 10  3.286307  3.296781  3.334431  3.336785  3.372082  3.313253
# 11  3.296781  3.334431  3.336785  3.372082  3.313253  3.346197
# 12  3.334431  3.336785  3.372082  3.313253  3.346197  3.437971
# 13  3.336785  3.372082  3.313253  3.346197  3.437971  3.423852
# 14  3.372082  3.313253  3.346197  3.437971  3.423852  3.442677
# 15  7.909001  7.978031  8.032654  8.061466  8.077073  7.984033
# 16  7.978031  8.032654  8.061466  8.077073  7.984033  7.918605
# 17  8.032654  8.061466  8.077073  7.984033  7.918605  7.802155
# 18  8.061466  8.077073  7.984033  7.918605  7.802155  7.832168
# 19  8.077073  7.984033  7.918605  7.802155  7.832168  7.900597
#
# [20 rows x 29 columns]

# %%
import tensorflow as tf

# %% [markdown]
# ## Deep Learning

# %%
def build_model():

    inp = tf.keras.Input(shape=(24, 1))

    x = tf.keras.layers.GRU(units=128, return_sequences=False)(inp)
    x = tf.keras.layers.Dense(1, activation="linear")(x)
    model = tf.keras.Model(inputs=inp, outputs=x)

    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.MeanSquaredError()
    model.compile(loss=loss, optimizer=opt)

    return model

# %%
model = build_model()

# %%
model.summary()
LR_MAX = 0.001
LR_MIN = 1e-6 
EPOCHS = 70
BATCH_SIZE = 100

# %%
# a simple cosine learning rate without restart
def lrfn(epoch_i, EPOCHS):

    decay_total_epochs = EPOCHS - 1
    phase = math.pi * epoch_i / decay_total_epochs  # 0 ~ pi
    cosine_decay = 0.5 * (1 + math.cos(phase))
    lr = (LR_MAX - LR_MIN) * cosine_decay + LR_MIN
    
    return lr

rng = [i for i in range(EPOCHS)]
lr_y = [lrfn(x, EPOCHS) for x in rng]
plt.figure(figsize=(5, 3))
plt.plot(rng, lr_y, '-o')
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(lr_y[0], max(lr_y), lr_y[-1]))
LR = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = 0)
plt.xlabel('Epoch',size=14)
plt.ylabel('Learning Rate',size=14)
plt.show()

# %%
# find the 50% percentile based on Active
print(f"timeseries shape: {timeseries.shape}, unique cfips: {timeseries['cfips'].nunique()}")
subset_df = timeseries[timeseries["active"] > timeseries["active"].quantile(0.5)]
print(f"subset_df shape after considering only larger pops: {subset_df.shape}, unique cfips: {subset_df['cfips'].nunique()}")
X_subset = subset_df.drop(
    ["target", "target_date", "cfips", "POPESTIMATE2021", "active"], axis=1
)
y_subset = subset_df["target"]
# Out:
# timeseries shape: (47025, 29), unique cfips: 3135
# subset_df shape after considering only larger pops: (23490, 29), unique cfips: 1566

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices("GPU")))
# train with gpu
result = None
with tf.device("/GPU:0"):
    result = model.fit(X_subset, y_subset, epochs=EPOCHS, batch_size=BATCH_SIZE,callbacks = [LR])
# Out:
# Num GPUs Available:  1
# Epoch 1/40
# 735/735 [==============================] - 8s 8ms/step - loss: 30.1435
# Epoch 2/40
# 735/735 [==============================] - 6s 8ms/step - loss: 17.9808
# Epoch 3/40
# 735/735 [==============================] - 6s 8ms/step - loss: 12.8781
# Epoch 4/40
# 735/735 [==============================] - 6s 8ms/step - loss: 9.6762
# Epoch 5/40
# 735/735 [==============================] - 6s 8ms/step - loss: 7.8404
# Epoch 6/40
# 735/735 [==============================] - 6s 8ms/step - loss: 6.6769
# Epoch 7/40
# 735/735 [==============================] - 6s 8ms/step - loss: 6.0886
# Epoch 8/40
# 735/735 [==============================] - 6s 8ms/step - loss: 5.7678
# Epoch 9/40
# 735/735 [==============================] - 6s 8ms/step - loss: 5.0718
# Epoch 10/40
# 735/735 [==============================] - 6s 8ms/step - loss: 4.5147
# Epoch 11/40
# 735/735 [==============================] - 6s 8ms/step - loss: 3.8707
# Epoch 12/40
# 735/735 [==============================] - 6s 8ms/step - loss: 4.1665
# Epoch 13/40
# 735/735 [==============================] - 6s 8ms/step - loss: 4.5075
# Epoch 14/40
# 735/735 [==============================] - 6s 8ms/step - loss: 3.9701
# Epoch 15/40
# 735/735 [==============================] - 6s 8ms/step - loss: 4.0918
# Epoch 16/40
# 735/735 [==============================] - 6s 8ms/step - loss: 4.2655
# Epoch 17/40
# 735/735 [==============================] - 6s 9ms/step - loss: 3.8507
# Epoch 18/40
# 735/735 [==============================] - 6s 8ms/step - loss: 3.1096
# Epoch 19/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.5416
# Epoch 20/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.7711
# Epoch 21/40
# 735/735 [==============================] - 6s 8ms/step - loss: 3.1040
# Epoch 22/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.9043
# Epoch 23/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.6923
# Epoch 24/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4653
# Epoch 25/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4174
# Epoch 26/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4166
# Epoch 27/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4547
# Epoch 28/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.3295
# Epoch 29/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.2010
# Epoch 30/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.2733
# Epoch 31/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.7096
# Epoch 32/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.5648
# Epoch 33/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4146
# Epoch 34/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4034
# Epoch 35/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.3800
# Epoch 36/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.2682
# Epoch 37/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.2914
# Epoch 38/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.1518
# Epoch 39/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.4893
# Epoch 40/40
# 735/735 [==============================] - 6s 8ms/step - loss: 2.1962

# %%
# plot the loss
fig = plt.figure(figsize=(10, 5))
plt.plot(result.history["loss"])
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ### Try LSTM 3 layers

# %%
model2 = tf.keras.Sequential()
model2.add(tf.keras.Input(shape=(24, 1)))
model2.add(tf.keras.layers.LSTM(75, return_sequences=True))
model2.add(tf.keras.layers.LSTM(units=30, return_sequences=True))
model2.add(tf.keras.layers.LSTM(units=30))
model2.add(tf.keras.layers.Dense(units=1))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.MeanSquaredError()
model2.compile(loss=loss, optimizer=opt)

# %%
model2.summary()
LR_MAX = 0.001
LR_MIN = 1e-6 
EPOCHS = 40
BATCH_SIZE = 500
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 24, 75)            23100
#
#  lstm_23 (LSTM)              (None, 24, 30)            12720
#
#  lstm_24 (LSTM)              (None, 30)                7320
#
#  dense_10 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 43,171
# Trainable params: 43,171
# Non-trainable params: 0
# _________________________________________________________________

# %%
# a simple cosine learning rate without restart
def lrfn(epoch_i, EPOCHS):

    decay_total_epochs = EPOCHS - 1
    phase = math.pi * epoch_i / decay_total_epochs  # 0 ~ pi
    cosine_decay = 0.5 * (1 + math.cos(phase))
    lr = (LR_MAX - LR_MIN) * cosine_decay + LR_MIN
    
    return lr

rng = [i for i in range(EPOCHS)]
lr_y = [lrfn(x, EPOCHS) for x in rng]
plt.figure(figsize=(5, 3))
plt.plot(rng, lr_y, '-o')
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(lr_y[0], max(lr_y), lr_y[-1]))
LR = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = 0)
plt.xlabel('Epoch',size=14)
plt.ylabel('Learning Rate',size=14)
plt.show()
# Out:
# Learning rate schedule: 0.001 to 0.001 to 1e-06

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices("GPU")))
# train with gpu
result = None
with tf.device("/GPU:0"):
    result = model2.fit(X_subset, y_subset, epochs=EPOCHS,batch_size=BATCH_SIZE, callbacks = [LR])
# Out:
# Num GPUs Available:  1
# Epoch 1/120
# 235/235 [==============================] - 5s 20ms/step - loss: 7.0610 - lr: 0.0010
# Epoch 2/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.9436 - lr: 1.0025e-06
# Epoch 3/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.9143 - lr: 0.0010
# Epoch 4/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.7848 - lr: 1.0222e-06
# Epoch 5/120
# 235/235 [==============================] - 5s 21ms/step - loss: 6.7609 - lr: 0.0010
# Epoch 6/120
# 235/235 [==============================] - 5s 21ms/step - loss: 6.6956 - lr: 1.0617e-06
# Epoch 7/120
# 235/235 [==============================] - 5s 21ms/step - loss: 6.6245 - lr: 0.0010
# Epoch 8/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.4814 - lr: 1.1210e-06
# Epoch 9/120
# 235/235 [==============================] - 5s 22ms/step - loss: 6.4956 - lr: 0.0010
# Epoch 10/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.3992 - lr: 1.2000e-06
# Epoch 11/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.3154 - lr: 0.0010
# Epoch 12/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.1928 - lr: 1.2988e-06
# Epoch 13/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6.1770 - lr: 0.0010
# Epoch 14/120
# 235/235 [==============================] - 5s 20ms/step - loss: 6
120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.9053 - lr: 9.9999e-04
# Epoch 98/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.8219 - lr: 2.4059e-05
# Epoch 99/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.8753 - lr: 9.9999e-04
# Epoch 100/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.8118 - lr: 2.5012e-05
# Epoch 101/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.8485 - lr: 9.9998e-04
# Epoch 102/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.8478 - lr: 2.5983e-05
# Epoch 103/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.8502 - lr: 9.9998e-04
# Epoch 104/120
# 235/235 [==============================] - 5s 22ms/step - loss: 2.8319 - lr: 2.6974e-05
# Epoch 105/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.8850 - lr: 9.9998e-04
# Epoch 106/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.8470 - lr: 2.7983e-05
# Epoch 107/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.9315 - lr: 9.9998e-04
# Epoch 108/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.6704 - lr: 2.9011e-05
# Epoch 109/120
# 235/235 [==============================] - 5s 21ms/step - loss: 3.6673 - lr: 9.9998e-04
# Epoch 110/120
# 235/235 [==============================] - 5s 22ms/step - loss: 3.0162 - lr: 3.0057e-05
# Epoch 111/120
# 235/235 [==============================] - 5s 21ms/step - loss: 3.1604 - lr: 9.9997e-04
# Epoch 112/120
# 235/235 [==============================] - 5s 22ms/step - loss: 2.8583 - lr: 3.1122e-05
# Epoch 113/120
# 235/235 [==============================] - 5s 21ms/step - loss: 2.8635 - lr: 9.9997e-04
# Epoch 114/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.5935 - lr: 3.2205e-05
# Epoch 115/120
# 235/235 [==============================] - 4s 19ms/step - loss: 2.6179 - lr: 9.9997e-04
# Epoch 116/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.6354 - lr: 3.3307e-05
# Epoch 117/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.6540 - lr: 9.9996e-04
# Epoch 118/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.5722 - lr: 3.4428e-05
# Epoch 119/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.5586 - lr: 9.9996e-04
# Epoch 120/120
# 235/235 [==============================] - 5s 20ms/step - loss: 2.4519 - lr: 3.5567e-05

# %% [markdown]
# ## Predictions

# %%
ids = test["cfips"].unique()
predictions = np.zeros((len(ids), 8))
test_df = timeseries[timeseries["target_date"] == timeseries["target_date"].max()].drop(
    ["target_date", "POPESTIMATE2021", "active", "cfips"], axis=1
)

# %%
timeseries.head(20)
# Out:
#     cfips  POPESTIMATE2021  active    target target_date         0         1  \
# 0    1001            59095    1249  3.219917  2021-08-01  3.007682  2.884870
# 1    1001            59095    1249  3.186722  2021-09-01  2.884870  3.055843
# 2    1001            59095    1249  3.203320  2021-10-01  3.055843  2.993233
# 3    1001            59095    1249  3.200948  2021-11-01  2.993233  2.993233
# 4    1001            59095    1249  3.286307  2021-12-01  2.993233  2.969090
# 5    1001            59095    1249  3.296781  2022-01-01  2.969090  2.909326
# 6    1001            59095    1249  3.334431  2022-02-01  2.909326  2.933231
# 7    1001            59095    1249  3.336785  2022-03-01  2.933231  3.000167
# 8    1001            59095    1249  3.372082  2022-04-01  3.000167  3.004948
# 9    1001            59095    1249  3.313253  2022-05-01  3.004948  3.019292
# 10   1001            59095    1249  3.346197  2022-06-01  3.019292  3.083837
# 11   1001            59095    1249  3.437971  2022-07-01  3.083837  3.174679
# 12   1001            59095    1249  3.423852  2022-08-01  3.174679  3.205756
# 13   1001            59095    1249  3.442677  2022-09-01  3.205756  3.193804
# 14   1001            59095    1249  3.463856  2022-10-01  3.193804  3.038416
# 59  1.247892  1.275998  1.326588  1.292861  1.315346  1.287240
# 74  1.748417  1.773202  1.831783  1.836289  1.852060  1.831783
#
# [5 rows x 24 columns]

# %%
test_df.shape
# Out:
# (3135, 24)

# %%
print("Start inference")
for i in range(8):
    predictions[:, i] = model.predict(test_df).reshape(-1)
    print(f"prediction{i+1} : {predictions[:, i]}")
    print(predictions.shape)
    test_df[i + 24] = predictions[:, i]
    test_df.drop(0, axis=1, inplace=True)
    test_df.columns = range(0, 24)
# Out:
# Start inference
# prediction1 : [3.44576025 8.33990192 1.34700274 ... 4.0132103  3.11206293 1.71794462]
# (3135, 8)
# prediction2 : [3.42427421 8.30612946 1.46344352 ... 4.02223301 3.12673759 1.66016293]
# (3135, 8)
# prediction3 : [3.41820788 8.27814102 1.55967021 ... 4.02823353 3.14724588 1.63242555]
# (3135, 8)
# prediction4 : [3.4182055  8.25641918 1.64362335 ... 4.02955055 3.15617561 1.64162755]
# (3135, 8)
# prediction5 : [3.42176437 8.23677921 1.72487593 ... 4.02857971 3.16108608 1.65035176]
# (3135, 8)
# prediction6 : [3.42640114 8.21484089 1.80067825 ... 4.02967453 3.16252947 1.64286232]
# (3135, 8)
# prediction7 : [3.43133998 8.19182968 1.87280226 ... 4.03550816 3.16121817 1.62101746]
# (3135, 8)
# prediction8 : [3.4343996  8.16620159 1.94143748 ... 4.0437603  3.15754604 1.59296107]
# (3135, 8)

# %%
test.sort_values(["cfips", "first_day_of_month"], inplace=True)

# %%
test["microbusiness_density"] = predictions.reshape(-1)

# %%
test.head(8)
# Out:
#                 row_id  cfips first_day_of_month  microbusiness_density
# 0      1001_2022-11-01   1001         2022-11-01               3.445760
# 3135   1001_2022-12-01   1001         2022-12-01               3.424274
# 6270   1001_2023-01-01   1001         2023-01-01               3.418208
# 9405   1001_2023-02-01   1001         2023-02-01               3.418205
# 12540  1001_2023-03-01   1001         2023-03-01               3.421764
# 15675  1001_2023-04-01   1001         2023-04-01               3.426401
# 18810  1001_2023-05-01   1001         2023-05-01               3.431340
# 21945  1001_2023-06-01   1001         2023-06-01               3.434400

# %%
result = test[["row_id", "microbusiness_density"]]
result.to_csv("../data/submissions/dl_test_1.csv", index=False)

# %% [markdown]
# ### Plot some stuff

# %%
for i in range(10):
    c = np.random.choice(ids)
    plot_df = train[train["cfips"] == c].copy()
    test_plot = test[test["cfips"] == c].copy()
    plot_df["first_day_of_month"]= pd.to_datetime(plot_df["first_day_of_month"])
    test_plot["first_day_of_month"]= pd.to_datetime(test_plot["first_day_of_month"])
    last_target = plot_df["microbusiness_density"].values[-1]

    fig, ax = plt.subplots(1, 1, figsize=(20, 8))
    plt.plot(
        plot_df["first_day_of_month"],
        plot_df["microbusiness_density"],
        "-o",
        label="train values",)
    plt.plot(
    test_plot["first_day_of_month"], test_plot["microbusiness_density"], "-^", label="predictions"
    )
    plt.title(f" cfips: {c}, county: {plot_df['county'].values[0]}")
    plt.legend()
    plt.show()
